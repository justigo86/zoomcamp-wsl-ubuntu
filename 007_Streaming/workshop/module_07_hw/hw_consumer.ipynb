# %%
from kafka import KafkaConsumer

#same as producer
server = 'localhost:9092'
topic_name = 'green-trips'

# %%
from dataclasses import dataclass

# create a class to ensure datatypes utilized
@dataclass
class Ride:
    lpep_pickup_datetime: int
    lpep_dropoff_datetime: int
    PULocationID: int
    DOLocationID: int
    passenger_count: float
    trip_distance: float
    tip_amount: float
    total_amount: float

# %%
import json

def ride_deserializer(data):
    json_str = data.decode('utf-8')
    ride_dict = json.loads(json_str)
    return Ride(**ride_dict)

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',  # reading from beginning - default is latest
    group_id='green-trips-console',  # creates group ID for tracking purposes / continuity
    value_deserializer=ride_deserializer
)

# %%
print(f"Listening to {topic_name}...")

count = 0
for message in consumer:
    ride = message.value
    if ride.trip_distance > 5.0:
        count += 1
    print(f"\n Number of trips greater than 5.0km: {count}")

consumer.close()
# Out:
# Listening to green-trips...
#
#  Number of trips greater than 5.0km: 0
#
#  Number of trips greater than 5.0km: 0
#
#  Number of trips greater than 5.0km: 0
#
#  Number of trips greater than 5.0km: 1
#
#  Number of trips greater than 5.0km: 1
#
#  Number of trips greater than 5.0km: 2
#
#  Number of trips greater than 5.0km: 2
#
#  Number of trips greater than 5.0km: 3
#
#  Number of trips greater than 5.0km: 4
#
#  Number of trips greater than 5.0km: 4
#
#  Number of trips greater than 5.0km: 4
#
#  Number of trips greater than 5.0km: 5
#
#  Number of trips greater than 5.0km: 5
#
#  Number of trips greater than 5.0km: 6
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 7
#
#  Number of trips greater than 5.0km: 8
#
#  Number of trips greater than 5.0km: 9
#
#  Number of trips greater than 5.0km: 9
#
#  Number of trips greater than 5.0km: 10
#
#  Number of trips greater than 5.0km: 10
#
#  Number of trips greater than 5.0km: 10
#
#  Number of trips greater than 5.0km: 10
#
#  Number of trips greater than 5.0km: 10
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 11
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 12
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 13
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 14
#
#  Number of trips greater than 5.0km: 15
#
#  Number of trips greater than 5.0km: 15
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 16
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 17
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 18
#
#  Number of trips greater than 5.0km: 19
#
#  Number of trips greater than 5.0km: 20
#
#  Number of trips greater than 5.0km: 20
#
#  Number of trips greater than 5.0km: 21
#
#  Number of trips greater than 5.0km: 21
#
#  Number of trips greater than 5.0km: 21
#
#  Number of trips greater than 5.0km: 21
#
#  Number of trips greater than 5.0km: 21
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 22
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 23
#
#  Number of trips greater than 5.0km: 24
#
#  Number of trips greater than 5.0km: 24
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 25
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 26
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 27
#
#  Number of trips greater than 5.0km: 28
#
#  Number of trips greater than 5.0km: 28
#
#  Number of trips greater than 5.0km: 28
#
#  Number of trips greater than 5.0km: 28
#
#  Number of trips greater than 5.0km: 28
#
#  Number of trips greater than 5.0km: 29
#
#  Number of trips greater than 5.0km: 29
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 30
#
#  Number of trips greater than 5.0km: 31
#
#  Number of trips greater than 5.0km: 31
#
#  Number of trips greater than 5.0km: 31
#
#  Number of trips greater than 5.0km: 31
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 32
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 33
#
#  Number of trips greater than 5.0km: 34
#
#  Number of trips greater than 5.0km: 34
#
#  Number of trips greater than 5.0km: 34
#
#  Number of trips greater than 5.0km: 34
#
#  Number of trips greater than 5.0km: 34
#
#  Number of trips greater than 5.0km: 35
#
#  Number of trips greater than 5.0km: 35
#
#  Number of trips greater than 5.0km: 35
#
#  Number of trips greater than 5.0km: 36
#
#  Number of trips greater than 5.0km: 36
#
#  Number of trips greater than 5.0km: 36
#
#  Number of trips greater than 5.0km: 36
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 37
#
#  Number of trips greater than 5.0km: 38
#
#  Number of trips greater than 5.0km: 38
#
#  Number of trips greater than 5.0km: 38
#
#  Number of trips greater than 5.0km: 38
#
#  Number of trips greater than 5.0km: 38
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 39
#
#  Number of trips greater than 5.0km: 40
#
#  Number of trips greater than 5.0km: 40
#
#  Number of trips greater than 5.0km: 41
#
#  Number of trips greater than 5.0km: 41
#
#  Number of trips greater than 5.0km: 41
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 42
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 43
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 44
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 45
#
#  Number of trips greater than 5.0km: 46
#
#  Number of trips greater than 5.0km: 46
#
#  Number of trips greater than 5.0km: 46
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 47
#
#  Number of trips greater than 5.0km: 48
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 49
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 50
#
#  Number of trips greater than 5.0km: 51
#
#  Number of trips greater than 5.0km: 51
#
#  Number of trips greater than 5.0km: 51
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 52
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 53
#
#  Number of trips greater than 5.0km: 54
#
#  Number of trips greater than 5.0km: 54
#
#  Number of trips greater than 5.0km: 54
#
#  Number of trips greater than 5.0km: 54
#
#  Number of trips greater than 5.0km: 55
#
#  Number of trips greater than 5.0km: 55
#
#  Number of trips greater than 5.0km: 55
#
#  Number of trips greater than 5.0km: 55
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 56
#
#  Number of trips greater than 5.0km: 57
#
#  Number of trips greater than 5.0km: 57
#
#  Number of trips greater than 5.0km: 57
#
#  Number of trips greater than 5.0km: 57
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 58
#
#  Number of trips greater than 5.0km: 59
#
#  Number of trips greater than 5.0km: 59
#
#  Number of trips greater than 5.0km: 59
#
#  Number of trips greater than 5.0km: 60
#
#  Number of trips greater than 5.0km: 60
#
#  Number of trips greater than 5.0km: 60
#
#  Number of trips greater than 5.0km: 60
#
#  Number of trips greater than 5.0km: 60
#
#  Number of trips greater than 5.0km: 61
#
#  Number of trips greater than 5.0km: 62
#
#  Number of trips greater than 5.0km: 62
#
#  Number of trips greater than 5.0km: 63
#
#  Number of trips greater than 5.0km: 63
#
#  Number of trips greater than 5.0km: 64
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 65
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 66
#
#  Number of trips greater than 5.0km: 67
#
#  Number of trips greater than 5.0km: 67
#
#  Number of trips greater than 5.0km: 67
#
#  Number of trips greater than 5.0km: 68
#
#  Number of trips greater than 5.0km: 68
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 69
#
#  Number of trips greater than 5.0km: 70
#
#  Number of trips greater than 5.0km: 70
#
#  Number of trips greater than 5.0km: 70
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 71
#
#  Number of trips greater than 5.0km: 72
#
#  Number of trips greater than 5.0km: 72
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 73
#
#  Number of trips greater than 5.0km: 74
#
#  Number of trips greater than 5.0km: 74
#
#  Number of trips greater than 5.0km: 74
#
#  Number of trips greater than 5.0km: 74
#
#  Number of trips greater than 5.0km: 75
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 76
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 77
#
#  Number of trips greater than 5.0km: 78
#
#  Number of trips greater than 5.0km: 78
#
#  Number of trips greater than 5.0km: 78
#
#  Number of trips greater than 5.0km: 78
#
#  Number of trips greater than 5.0km: 78
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 79
#
#  Number of trips greater than 5.0km: 80
#
#  Number of trips greater than 5.0km: 80
#
#  Number of trips greater than 5.0km: 81
#
#  Number of trips greater than 5.0km: 81
#
#  Number of trips greater than 5.0km: 82
#
#  Number of trips greater than 5.0km: 83
#
#  Number of trips greater than 5.0km: 83
#
#  Number of trips greater than 5.0km: 83
#
#  Number of trips greater than 5.0km: 84
#
#  Number of trips greater than 5.0km: 84
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 85
#
#  Number of trips greater than 5.0km: 86
#
#  Number of trips greater than 5.0km: 86
#
#  Number of trips greater than 5.0km: 86
#
#  Number of trips greater than 5.0km: 86
#
#  Number of trips greater than 5.0km: 87
#
#  Number of trips greater than 5.0km: 87
#
#  Number of trips greater than 5.0km: 87
#
#  Number of trips greater than 5.0km: 87
#
#  Number of trips greater than 5.0km: 87
#
#  Number of trips greater than 5.0km: 88
#
#  Number of trips greater than 5.0km: 89
#
#  Number of trips greater than 5.0km: 89
#
#  Number of trips greater than 5.0km: 89
#
#  Number of trips greater than 5.0km: 90
#
#  Number of trips greater than 5.0km: 90
#
#  Number of trips greater than 5.0km: 91
#
#  Number of trips greater than 5.0km: 92
#
#  Number of trips greater than 5.0km: 92
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 93
#
#  Number of trips greater than 5.0km: 94
#
#  Number of trips greater than 5.0km: 95
#
#  Number of trips greater than 5.0km: 95
#
#  Number of trips greater than 5.0km: 96
#
#  Number of trips greater than 5.0km: 97
#
#  Number of trips greater than 5.0km: 98
#
#  Number of trips greater than 5.0km: 98
#
#  Number of trips greater than 5.0km: 98
#
#  Number of trips greater than 5.0km: 98
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 99
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 100
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 101
#
#  Number of trips greater than 5.0km: 102
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 103
#
#  Number of trips greater than 5.0km: 104
#
#  Number of trips greater than 5.0km: 104
#
#  Number of trips greater than 5.0km: 104
#
#  Number of trips greater than 5.0km: 105
#
#  Number of trips greater than 5.0km: 105
#
#  Number of trips greater than 5.0km: 105
#
#  Number of trips greater than 5.0km: 106
#
#  Number of trips greater than 5.0km: 106
#
#  Number of trips greater than 5.0km: 106
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 107
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 108
#
#  Number of trips greater than 5.0km: 109
#
#  Number of trips greater than 5.0km: 109
#
#  Number of trips greater than 5.0km: 109
#
#  Number of trips greater than 5.0km: 109
#
#  Number of trips greater than 5.0km: 109
#
#  Number of trips greater than 5.0km: 110
#
#  Number of trips greater than 5.0km: 110
#
#  Number of trips greater than 5.0km: 110
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 111
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 112
#
#  Number of trips greater than 5.0km: 113
#
#  Number of trips greater than 5.0km: 113
#
#  Number of trips greater than 5.0km: 113
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 114
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 115
#
#  Number of trips greater than 5.0km: 116
#
#  Number of trips greater than 5.0km: 116
#
#  Number of trips greater than 5.0km: 116
#
#  Number of trips greater than 5.0km: 116
#
#  Number of trips greater than 5.0km: 116
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 117
#
#  Number of trips greater than 5.0km: 118
#
#  Number of trips greater than 5.0km: 118
#
#  Number of trips greater than 5.0km: 118
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 119
#
#  Number of trips greater than 5.0km: 120
#
#  Number of trips greater than 5.0km: 120
#
#  Number of trips greater than 5.0km: 120
#
#  Number of trips greater than 5.0km: 120
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 121
#
#  Number of trips greater than 5.0km: 122
#
#  Number of trips greater than 5.0km: 122
#
#  Number of trips greater than 5.0km: 122
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 123
#
#  Number of trips greater than 5.0km: 124
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 125
#
#  Number of trips greater than 5.0km: 126
#
#  Number of trips greater than 5.0km: 126
#
#  Number of trips greater than 5.0km: 126
#
#  Number of trips greater than 5.0km: 126
#
#  Number of trips greater than 5.0km: 127
#
#  Number of trips greater than 5.0km: 127
#
#  Number of trips greater than 5.0km: 127
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 128
#
#  Number of trips greater than 5.0km: 129
#
#  Number of trips greater than 5.0km: 129
#
#  Number of trips greater than 5.0km: 129
#
#  Number of trips greater than 5.0km: 129
#
#  Number of trips greater than 5.0km: 129
#
#  Number of trips greater than 5.0km: 130
#
#  Number of trips greater than 5.0km: 130
#
#  Number of trips greater than 5.0km: 131
#
#  Number of trips greater than 5.0km: 131
#
#  Number of trips greater than 5.0km: 131
#
#  Number of trips greater than 5.0km: 131
#
#  Number of trips greater than 5.0km: 131
#
#  Number of trips greater than 5.0km: 132
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 133
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 134
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 135
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 136
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 137
#
#  Number of trips greater than 5.0km: 138
#
#  Number of trips greater than 5.0km: 139
#
#  Number of trips greater than 5.0km: 139
#
#  Number of trips greater than 5.0km: 139
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 140
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 141
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 142
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 143
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 144
#
#  Number of trips greater than 5.0km: 145
#
#  Number of trips greater than 5.0km: 145
#
#  Number of trips greater than 5.0km: 145
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 146
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 147
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 148
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 149
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 150
#
#  Number of trips greater than 5.0km: 151
#
#  Number of trips greater than 5.0km: 152
#
#  Number of trips greater than 5.0km: 152
#
#  Number of trips greater than 5.0km: 152
#
#  Number of trips greater than 5.0km: 152
#
#  Number of trips greater than 5.0km: 153
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 154
#
#  Number of trips greater than 5.0km: 155
#
#  Number of trips greater than 5.0km: 155
#
#  Number of trips greater than 5.0km: 155
#
#  Number of trips greater than 5.0km: 155
#
#  Number of trips greater than 5.0km: 155
#
#  Number of trips greater than 5.0km: 155
#
# ...
#
#  Number of trips greater than 5.0km: 8354
#
#  Number of trips greater than 5.0km: 8354
#
#  Number of trips greater than 5.0km: 8355
#
#  Number of trips greater than 5.0km: 8356
#
#  Number of trips greater than 5.0km: 8356
#
#  Number of trips greater than 5.0km: 8357
#
#  Number of trips greater than 5.0km: 8357
#
#  Number of trips greater than 5.0km: 8358
#
#  Number of trips greater than 5.0km: 8359
#
#  Number of trips greater than 5.0km: 8359
#
#  Number of trips greater than 5.0km: 8359
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8360
#
#  Number of trips greater than 5.0km: 8361
#
#  Number of trips greater than 5.0km: 8361
#
#  Number of trips greater than 5.0km: 8361
#
#  Number of trips greater than 5.0km: 8361
#
#  Number of trips greater than 5.0km: 8362
#
#  Number of trips greater than 5.0km: 8363
#
#  Number of trips greater than 5.0km: 8364
#
#  Number of trips greater than 5.0km: 8365
#
#  Number of trips greater than 5.0km: 8365
#
#  Number of trips greater than 5.0km: 8366
#
#  Number of trips greater than 5.0km: 8366
#
#  Number of trips greater than 5.0km: 8367
#
#  Number of trips greater than 5.0km: 8368
#
#  Number of trips greater than 5.0km: 8369
#
#  Number of trips greater than 5.0km: 8370
#
#  Number of trips greater than 5.0km: 8370
#
#  Number of trips greater than 5.0km: 8370
#
#  Number of trips greater than 5.0km: 8371
#
#  Number of trips greater than 5.0km: 8371
#
#  Number of trips greater than 5.0km: 8371
#
#  Number of trips greater than 5.0km: 8372
#
#  Number of trips greater than 5.0km: 8372
#
#  Number of trips greater than 5.0km: 8372
#
#  Number of trips greater than 5.0km: 8372
#
#  Number of trips greater than 5.0km: 8372
#
#  Number of trips greater than 5.0km: 8373
#
#  Number of trips greater than 5.0km: 8373
#
#  Number of trips greater than 5.0km: 8374
#
#  Number of trips greater than 5.0km: 8374
#
#  Number of trips greater than 5.0km: 8374
#
#  Number of trips greater than 5.0km: 8374
#
#  Number of trips greater than 5.0km: 8375
#
#  Number of trips greater than 5.0km: 8375
#
#  Number of trips greater than 5.0km: 8375
#
#  Number of trips greater than 5.0km: 8375
#
#  Number of trips greater than 5.0km: 8376
#
#  Number of trips greater than 5.0km: 8376
#
#  Number of trips greater than 5.0km: 8377
#
#  Number of trips greater than 5.0km: 8378
#
#  Number of trips greater than 5.0km: 8379
#
#  Number of trips greater than 5.0km: 8379
#
#  Number of trips greater than 5.0km: 8380
#
#  Number of trips greater than 5.0km: 8381
#
#  Number of trips greater than 5.0km: 8382
#
#  Number of trips greater than 5.0km: 8383
#
#  Number of trips greater than 5.0km: 8384
#
#  Number of trips greater than 5.0km: 8384
#
#  Number of trips greater than 5.0km: 8384
#
#  Number of trips greater than 5.0km: 8384
#
#  Number of trips greater than 5.0km: 8384
#
#  Number of trips greater than 5.0km: 8385
#
#  Number of trips greater than 5.0km: 8385
#
#  Number of trips greater than 5.0km: 8386
#
#  Number of trips greater than 5.0km: 8386
#
#  Number of trips greater than 5.0km: 8387
#
#  Number of trips greater than 5.0km: 8388
#
#  Number of trips greater than 5.0km: 8389
#
#  Number of trips greater than 5.0km: 8390
#
#  Number of trips greater than 5.0km: 8391
#
#  Number of trips greater than 5.0km: 8392
#
#  Number of trips greater than 5.0km: 8393
#
#  Number of trips greater than 5.0km: 8393
#
#  Number of trips greater than 5.0km: 8394
#
#  Number of trips greater than 5.0km: 8395
#
#  Number of trips greater than 5.0km: 8395
#
#  Number of trips greater than 5.0km: 8396
#
#  Number of trips greater than 5.0km: 8396
#
#  Number of trips greater than 5.0km: 8397
#
#  Number of trips greater than 5.0km: 8397
#
#  Number of trips greater than 5.0km: 8398
#
#  Number of trips greater than 5.0km: 8398
#
#  Number of trips greater than 5.0km: 8399
#
#  Number of trips greater than 5.0km: 8400
#
#  Number of trips greater than 5.0km: 8401
#
#  Number of trips greater than 5.0km: 8402
#
#  Number of trips greater than 5.0km: 8403
#
#  Number of trips greater than 5.0km: 8404
#
#  Number of trips greater than 5.0km: 8405
#
#  Number of trips greater than 5.0km: 8405
#
#  Number of trips greater than 5.0km: 8406
#
#  Number of trips greater than 5.0km: 8406
#
#  Number of trips greater than 5.0km: 8407
#
#  Number of trips greater than 5.0km: 8408
#
#  Number of trips greater than 5.0km: 8409
#
#  Number of trips greater than 5.0km: 8410
#
#  Number of trips greater than 5.0km: 8411
#
#  Number of trips greater than 5.0km: 8412
#
#  Number of trips greater than 5.0km: 8413
#
#  Number of trips greater than 5.0km: 8414
#
#  Number of trips greater than 5.0km: 8414
#
#  Number of trips greater than 5.0km: 8415
#
#  Number of trips greater than 5.0km: 8416
#
#  Number of trips greater than 5.0km: 8417
#
#  Number of trips greater than 5.0km: 8418
#
#  Number of trips greater than 5.0km: 8418
#
#  Number of trips greater than 5.0km: 8419
#
#  Number of trips greater than 5.0km: 8419
#
#  Number of trips greater than 5.0km: 8420
#
#  Number of trips greater than 5.0km: 8421
#
#  Number of trips greater than 5.0km: 8422
#
#  Number of trips greater than 5.0km: 8423
#
#  Number of trips greater than 5.0km: 8424
#
#  Number of trips greater than 5.0km: 8425
#
#  Number of trips greater than 5.0km: 8426
#
#  Number of trips greater than 5.0km: 8426
#
#  Number of trips greater than 5.0km: 8427
#
#  Number of trips greater than 5.0km: 8427
#
#  Number of trips greater than 5.0km: 8428
#
#  Number of trips greater than 5.0km: 8429
#
#  Number of trips greater than 5.0km: 8430
#
#  Number of trips greater than 5.0km: 8431
#
#  Number of trips greater than 5.0km: 8432
#
#  Number of trips greater than 5.0km: 8432
#
#  Number of trips greater than 5.0km: 8433
#
#  Number of trips greater than 5.0km: 8433
#
#  Number of trips greater than 5.0km: 8433
#
#  Number of trips greater than 5.0km: 8434
#
#  Number of trips greater than 5.0km: 8435
#
#  Number of trips greater than 5.0km: 8435
#
#  Number of trips greater than 5.0km: 8435
#
#  Number of trips greater than 5.0km: 8436
#
#  Number of trips greater than 5.0km: 8436
#
#  Number of trips greater than 5.0km: 8437
#
#  Number of trips greater than 5.0km: 8438
#
#  Number of trips greater than 5.0km: 8439
#
#  Number of trips greater than 5.0km: 8439
#
#  Number of trips greater than 5.0km: 8440
#
#  Number of trips greater than 5.0km: 8441
#
#  Number of trips greater than 5.0km: 8442
#
#  Number of trips greater than 5.0km: 8442
#
#  Number of trips greater than 5.0km: 8442
#
#  Number of trips greater than 5.0km: 8443
#
#  Number of trips greater than 5.0km: 8444
#
#  Number of trips greater than 5.0km: 8444
#
#  Number of trips greater than 5.0km: 8444
#
#  Number of trips greater than 5.0km: 8444
#
#  Number of trips greater than 5.0km: 8445
#
#  Number of trips greater than 5.0km: 8446
#
#  Number of trips greater than 5.0km: 8447
#
#  Number of trips greater than 5.0km: 8448
#
#  Number of trips greater than 5.0km: 8448
#
#  Number of trips greater than 5.0km: 8448
#
#  Number of trips greater than 5.0km: 8448
#
#  Number of trips greater than 5.0km: 8448
#
#  Number of trips greater than 5.0km: 8449
#
#  Number of trips greater than 5.0km: 8449
#
#  Number of trips greater than 5.0km: 8450
#
#  Number of trips greater than 5.0km: 8450
#
#  Number of trips greater than 5.0km: 8451
#
#  Number of trips greater than 5.0km: 8452
#
#  Number of trips greater than 5.0km: 8453
#
#  Number of trips greater than 5.0km: 8454
#
#  Number of trips greater than 5.0km: 8455
#
#  Number of trips greater than 5.0km: 8455
#
#  Number of trips greater than 5.0km: 8456
#
#  Number of trips greater than 5.0km: 8456
#
#  Number of trips greater than 5.0km: 8457
#
#  Number of trips greater than 5.0km: 8457
#
#  Number of trips greater than 5.0km: 8458
#
#  Number of trips greater than 5.0km: 8459
#
#  Number of trips greater than 5.0km: 8459
#
#  Number of trips greater than 5.0km: 8460
#
#  Number of trips greater than 5.0km: 8460
#
#  Number of trips greater than 5.0km: 8461
#
#  Number of trips greater than 5.0km: 8461
#
#  Number of trips greater than 5.0km: 8461
#
#  Number of trips greater than 5.0km: 8462
#
#  Number of trips greater than 5.0km: 8462
#
#  Number of trips greater than 5.0km: 8463
#
#  Number of trips greater than 5.0km: 8464
#
#  Number of trips greater than 5.0km: 8465
#
#  Number of trips greater than 5.0km: 8465
#
#  Number of trips greater than 5.0km: 8465
#
#  Number of trips greater than 5.0km: 8465
#
#  Number of trips greater than 5.0km: 8465
#
#  Number of trips greater than 5.0km: 8466
#
#  Number of trips greater than 5.0km: 8466
#
#  Number of trips greater than 5.0km: 8467
#
#  Number of trips greater than 5.0km: 8467
#
#  Number of trips greater than 5.0km: 8468
#
#  Number of trips greater than 5.0km: 8468
#
#  Number of trips greater than 5.0km: 8469
#
#  Number of trips greater than 5.0km: 8470
#
#  Number of trips greater than 5.0km: 8470
#
#  Number of trips greater than 5.0km: 8470
#
#  Number of trips greater than 5.0km: 8471
#
#  Number of trips greater than 5.0km: 8471
#
#  Number of trips greater than 5.0km: 8471
#
#  Number of trips greater than 5.0km: 8472
#
#  Number of trips greater than 5.0km: 8473
#
#  Number of trips greater than 5.0km: 8473
#
#  Number of trips greater than 5.0km: 8473
#
#  Number of trips greater than 5.0km: 8474
#
#  Number of trips greater than 5.0km: 8474
#
#  Number of trips greater than 5.0km: 8475
#
#  Number of trips greater than 5.0km: 8476
#
#  Number of trips greater than 5.0km: 8477
#
#  Number of trips greater than 5.0km: 8478
#
#  Number of trips greater than 5.0km: 8478
#
#  Number of trips greater than 5.0km: 8479
#
#  Number of trips greater than 5.0km: 8480
#
#  Number of trips greater than 5.0km: 8481
#
#  Number of trips greater than 5.0km: 8481
#
#  Number of trips greater than 5.0km: 8482
#
#  Number of trips greater than 5.0km: 8483
#
#  Number of trips greater than 5.0km: 8484
#
#  Number of trips greater than 5.0km: 8485
#
#  Number of trips greater than 5.0km: 8486
#
#  Number of trips greater than 5.0km: 8487
#
#  Number of trips greater than 5.0km: 8487
#
#  Number of trips greater than 5.0km: 8487
#
#  Number of trips greater than 5.0km: 8487
#
#  Number of trips greater than 5.0km: 8488
#
#  Number of trips greater than 5.0km: 8489
#
#  Number of trips greater than 5.0km: 8490
#
#  Number of trips greater than 5.0km: 8490
#
#  Number of trips greater than 5.0km: 8490
#
#  Number of trips greater than 5.0km: 8491
#
#  Number of trips greater than 5.0km: 8491
#
#  Number of trips greater than 5.0km: 8491
#
#  Number of trips greater than 5.0km: 8492
#
#  Number of trips greater than 5.0km: 8492
#
#  Number of trips greater than 5.0km: 8493
#
#  Number of trips greater than 5.0km: 8494
#
#  Number of trips greater than 5.0km: 8495
#
#  Number of trips greater than 5.0km: 8495
#
#  Number of trips greater than 5.0km: 8495
#
#  Number of trips greater than 5.0km: 8496
#
#  Number of trips greater than 5.0km: 8496
#
#  Number of trips greater than 5.0km: 8496
#
#  Number of trips greater than 5.0km: 8496
#
#  Number of trips greater than 5.0km: 8497
#
#  Number of trips greater than 5.0km: 8497
#
#  Number of trips greater than 5.0km: 8497
#
#  Number of trips greater than 5.0km: 8498
#
#  Number of trips greater than 5.0km: 8498
#
#  Number of trips greater than 5.0km: 8499
#
#  Number of trips greater than 5.0km: 8499
#
#  Number of trips greater than 5.0km: 8499
#
#  Number of trips greater than 5.0km: 8500
#
#  Number of trips greater than 5.0km: 8500
#
#  Number of trips greater than 5.0km: 8501
#
#  Number of trips greater than 5.0km: 8501
#
#  Number of trips greater than 5.0km: 8501
#
#  Number of trips greater than 5.0km: 8501
#
#  Number of trips greater than 5.0km: 8501
#
#  Number of trips greater than 5.0km: 8502
#
#  Number of trips greater than 5.0km: 8503
#
#  Number of trips greater than 5.0km: 8504
#
#  Number of trips greater than 5.0km: 8504
#
#  Number of trips greater than 5.0km: 8504
#
#  Number of trips greater than 5.0km: 8504
#
#  Number of trips greater than 5.0km: 8504
#
#  Number of trips greater than 5.0km: 8505
#
#  Number of trips greater than 5.0km: 8506
#
#  Number of trips greater than 5.0km: 8506
#
#  Number of trips greater than 5.0km: 8506
#
#  Number of trips greater than 5.0km: 8506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 print(f"Listening to {topic_name}...")
#       3 count = 0
# ----> 4 for message in consumer:
#       5     ride = message.value
#       6     if ride.trip_distance > 5.0:
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/projects/DataTalksZoomcamp/007_Streaming/workshop/.venv/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /usr/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
