# %%
from kafka import KafkaConsumer

#same as producer
server = 'localhost:9092'
topic_name = 'rides'

# %%
from models import ride_deserializer

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',  # reading from beginning - default is latest
    group_id='rides-to-postgres',  # creates group ID for tracking purposes / continuity
    value_deserializer=ride_deserializer
)

# %%
# up to this point - largely same as consumer.ipynb (diff group_id)
# now different for postgres table

# connect to postgreSQL
import psycopg2

conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)
conn.autocommit = True
cur = conn.cursor()
